# %% [markdown]
# ![](https://t-mobile.scene7.com/is/image/Tmusprod/netflix-hero.desktop?wid=1280&hei=360&fmt=png-alpha)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![](https://www.somagnews.com/wp-content/uploads/2021/12/Netflix-1.jpg)

# %%
data=pd.read_csv('netflix.csv')              ##### read dataframe
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.shape                             ## find data structure shape rows and column
# Out:
# (8807, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.memory_usage()                        ##### data memory usage
# Out:
# Index             128
# show_id         70456
# type            70456
# title           70456
# director        70456
# cast            70456
# country         70456
# date_added      70456
# release_year    70456
# rating          70456
# duration        70456
# listed_in       70456
# description     70456
# dtype: int64

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.index                           #### index information
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.size             ######## this is entire data element count
# Out:
# 105684

# %%
data.dtypes              ####### show the datatype each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.head(5)       ### first 5 rows
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data.tail(5)     ###### last 5 rows
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 8802  20-Nov-19          2007      R    158 min
# 8803   1-Jul-19          2018  TV-Y7  2 Seasons
# 8804   1-Nov-19          2009      R     88 min
# ...

# %%
data.duplicated()         ##### find duplicated values in dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ##  IS THERE ANY NULL VALUE PRESENT IN ANY COLUMN? SHOW WITH HIT-MAP

# %%
data.isnull()                #### to show where null value is present
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()                                     ####### to show the count of null values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())                            ######## using hitmap to show null value count
# Out:
# <AxesSubplot:>

# %%
data.title                #### only title column info
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
data[data['title'].isin(['Zombieland'])]          ###### show all records of particulr item in any column
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
#
#      date_added  release_year rating duration                listed_in  \
# 8804   1-Nov-19          2009      R   88 min  Comedies, Horror Movies
#
#                                             description
# 8804  Looking to survive in a world taken over by zo...

# %%
data.max()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_19876/2904433368.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.max()
# show_id                                                      s999
# type                                                      TV Show
# title                                         최강전사 미니특공대 : 영웅의 탄생
# release_year                                                 2021
# listed_in                                               Thrillers
# description     “Last Chance U” hits the hardwood in East Los ...
# dtype: object

# %%
data.min()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_19876/927168777.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.min()
# show_id                                                        s1
# type                                                        Movie
# title                                                      #Alive
# release_year                                                 1925
# listed_in                                      Action & Adventure
# description     "Bridgerton" cast members share behind-the-sce...
# dtype: object

# %% [markdown]
# # which year highest number of the tv shows & movies where realeased? show with bar graph

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['Date_N']=pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()   #### count the occurence of all individual years in date coulmn [ans is =2019]
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar',color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # HOW MANY MOVIES & TV SHOWS ARE IN THE DATASET ?  SHOW WITH BAR GRAPH

# %%
data.groupby('type').type.count ()       ########## groupby title through  find count of movies and tv shows
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data['type'])
# Out:
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# # SHOW ALL THE MOVIES THAT WHERE RELEASED IN YEAR 2021

# %%
data.release_year
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2007
# 8803    2018
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 8807, dtype: int64

# %%
data.release_year.min()
# Out:
# 1925

# %%
data['release_year']=data['Date_N'].dt.year
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21        2021.0  PG-13     90 min
# 1  24-Sep-21        2021.0  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data[(data['type'] == 'Movie') & (data['release_year'] == 2021)]              ###### only 2021 year all movies
# Out:
#      show_id   type                                           title  \
# 0         s1  Movie                            Dick Johnson Is Dead
# 6         s7  Movie                My Little Pony: A New Generation
# 7         s8  Movie                                         Sankofa
# 9        s10  Movie                                    The Starling
# 12       s13  Movie                                    Je Suis Karl
# ...      ...    ...                                             ...
# 8187   s8188  Movie                          The American President
# 8272   s8273  Movie                                    The Departed
# 8320   s8321  Movie                 The Girl with the Dragon Tattoo
# 8434   s8435  Movie  The Naked Gun: From the Files of Police Squad!
# 8461   s8462  Movie                               The Polar Express
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...

# %% [markdown]
# # SHOW ONLY 2021 YEAR IN INDIA  ALL INFORMATION

# %%
data[(data['country']=='India')& (data['release_year'] == 2021)]      ##### if we want only one country details with year 2021
# Out:
#      show_id     type                               title     director  \
# 4         s5  TV Show                        Kota Factory          NaN
# 24       s25    Movie                               Jeans   S. Shankar
# 39       s40  TV Show                        Chhota Bheem          NaN
# 50       s51  TV Show                       Dharmakshetra          NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan          NaN
# ...      ...      ...                                 ...          ...
# 1422   s1423    Movie                            Apaharan  Prakash Jha
# 1423   s1424    Movie                        BluffMaster!  Rohan Sippy
# 1426   s1427    Movie                           Gangaajal  Prakash Jha
# 1429   s1430  TV Show  Mighty Little Bheem: Kite Festival          NaN
# 1441   s1442    Movie                       Hello Brother  Sohail Khan
#
#                                                    cast country date_added  \
# ...

# %% [markdown]
# # SHOW ONLY THE TITLE OF ALL TV SHOWS THAT WHERE RELEASED IN YEAR 2021 INDIA ONLY

# %%
data[(data['country']=='India')& (data['type'] == 'TV Show') & (data['release_year']==2021)]
# Out:
#      show_id     type                               title  \
# 4         s5  TV Show                        Kota Factory
# 39       s40  TV Show                        Chhota Bheem
# 50       s51  TV Show                       Dharmakshetra
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan
# 69       s70  TV Show      Stories by Rabindranath Tagore
# 266     s267  TV Show                The Creative Indians
# 297     s298  TV Show                            Navarasa
# 876     s877  TV Show                        Alma Matters
# 911     s912  TV Show                    Sab Jholmaal Hai
# 918     s919  TV Show                      Lava Ka Dhaava
# 1093   s1094  TV Show                         The Big Day
# 1227   s1228  TV Show                       Bombay Begums
# 1282   s1283  TV Show                    Zindagi in Short
# 1293   s1294  TV Show                       Pitta Kathalu
# 1429   s1430  TV Show  Mighty Little Bheem: Kite Festival
#
# ...

# %%
data[(data['country']=='India')& (data['type'] == 'TV Show')&(data['release_year']==2021)]['title']  ### 2021 title only
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
# 266                   The Creative Indians
# 297                               Navarasa
# 876                           Alma Matters
# 911                       Sab Jholmaal Hai
# 918                         Lava Ka Dhaava
# 1093                           The Big Day
# 1227                         Bombay Begums
# 1282                      Zindagi in Short
# 1293                         Pitta Kathalu
# 1429    Mighty Little Bheem: Kite Festival
# Name: title, dtype: object

# %% [markdown]
# # TOP 10 DIRECTORS, WHO GAVE THE HIGHEST NUMBER OF TV SHOWS & MOVIES TO NETFLIX

# %%
data['director'].value_counts().head(10)            ######## top 10 directors
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
data['director'].value_counts().tail(10)           ##### last 10 director
# Out:
# Azazel Jacobs                     1
# Jung Ji-woo                       1
# Matt D'Avella                     1
# Parthiban                         1
# Scott McAboy                      1
# Raymie Muzquiz, Stu Livingston    1
# Joe Menendez                      1
# Eric Bross                        1
# Will Eisenberg                    1
# Mozez Singh                       1
# Name: director, dtype: int64

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21        2021.0  PG-13     90 min
# 1  24-Sep-21        2021.0  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data.cast
# Out:
# 0                                                     NaN
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                  NaN
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %% [markdown]
# ## HOW MANY MOVIES/SHOW, PATICULAR DIRECTOR WAS CAST?

# %%
data[(data['cast']=='Vicky Kaushal')]  ############ single name not prperly get results
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N]
# Index: []

# %% [markdown]
# # CREATING NEW DATAFRAME

# %%
dataframe=data.dropna()
dataframe.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country date_added  release_year  \
# 7  United States, Ghana, Burkina Faso, United Kin...  24-Sep-21        2021.0
# 8                                     United Kingdom  24-Sep-21        2021.0
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24
# ...

# %%
dataframe.shape
# Out:
# (5332, 13)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332 entries, 7 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   float64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
#  12  Date_N        5332 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(11)
# memory usage: 583.2+ KB

# %%
dataframe.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2018.825956
# std        1.540456
# min     2008.000000
# 25%     2018.000000
# 50%     2019.000000
# 75%     2020.000000
# max     2021.000000

# %%
dataframe.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year           float64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
dataframe.isna()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 7       False  False  False     False  False    False       False
# 8       False  False  False     False  False    False       False
# 9       False  False  False     False  False    False       False
# 12      False  False  False     False  False    False       False
# 24      False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8801    False  False  False     False  False    False       False
# 8802    False  False  False     False  False    False       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description  Date_N
# 7            False   False     False      False        False   False
# ...

# %% [markdown]
# # WHAT ARE THE DIFERENT RATINGS DEFINED BY NETFLIX?

# %%
data['rating'].nunique()
# Out:
# 17

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
data.country
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %% [markdown]
# # HOW MANY MOVIES GOT THE 'PG-13' RATING IN INDIA?

# %%
data[(data['type']=='Movie') & (data['rating']=='PG-13')& (data['country']=='India')]
# Out:
#      show_id   type        title         director  \
# 1114   s1115  Movie     3 Idiots  Rajkumar Hirani
# 4693   s4694  Movie      Pad Man         R. Balki
# 5151   s5152  Movie  Poster Boys  Shreyas Talpade
# 5183   s5184  Movie    Mubarakan     Anees Bazmee
#
#                                                    cast country date_added  \
# 1114  Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...   India   1-Apr-21
# 4693  Akshay Kumar, Sonam Kapoor, Radhika Apte, Jyot...   India  21-Aug-18
# 5151  Sunny Deol, Bobby Deol, Shreyas Talpade, Sonal...   India  27-Nov-17
# 5183  Anil Kapoor, Arjun Kapoor, Ileana D'Cruz, Athi...   India   5-Nov-17
#
#       release_year rating duration  \
# 1114        2021.0  PG-13  164 min
# 4693        2018.0  PG-13  130 min
# 5151        2017.0  PG-13  128 min
# 5183        2017.0  PG-13  153 min
#
#                                           listed_in  \
# 1114         Comedies, Dramas, International Movies
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='PG-13')& (data['country']=='India')].shape      ### ans = 4
# Out:
# (4, 13)

# %% [markdown]
# # HOW MANY TV SHOW GOT THE 'TV-14'RATING BEFOR YEAR 2021?

# %%
data[(data['type']=='TV Show') & (data['rating']=='TV-14') & (data['release_year'] < 2021)]
# Out:
#      show_id     type                           title director  \
# 1473   s1474  TV Show  Chilling Adventures of Sabrina      NaN
# 1480   s1481  TV Show                      Still Game      NaN
# 1503   s1504  TV Show          Lovestruck in the City      NaN
# 1538   s1539  TV Show         Marvel Anime: Wolverine      NaN
# 1539   s1540  TV Show             Marvel Anime: X-Men      NaN
# ...      ...      ...                             ...      ...
# 8690   s8691  TV Show                         Wake Up      NaN
# 8720   s8721  TV Show       What Happens to My Family      NaN
# 8721   s8722  TV Show                   What Is Love?      NaN
# 8736   s8737  TV Show                   Who's the One      NaN
# 8755   s8756  TV Show               Women Behind Bars      NaN
#
#                                                    cast               country  \
# 1473  Kiernan Shipka, Ross Lynch, Miranda Otto, Lucy...         United States
# ...

# %%
data[(data['type']=='TV Show') & (data['rating']=='TV-14') & (data['release_year'] < 2021)].shape
# Out:
# (604, 13)

# %% [markdown]
# # WHAT IS THE MAXIMUM DURATION OF A MOVIE/SHOW ON NETFLIX?

# %%
data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data['duration'].dtypes
# Out:
# dtype('O')

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Date_N'],
#       dtype='object')

# %% [markdown]
# # SORT THE DATASET BY YEAR

# %%
data.sort_values(by='release_year')
# Out:
#      show_id     type                         title              director  \
# 5957   s5958    Movie          To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show               Dinner for Five                   NaN
# 5956   s5957    Movie       Just Another Love Story          Ole Bornedal
# 5955   s5956    Movie                      Splatter             Joe Dante
# 7370   s7371    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 7196   s7197  TV Show                      Kikoriki                   NaN
# 7254   s7255  TV Show           La Familia P. Luche                   NaN
# 7406   s7407  TV Show                         Maron                   NaN
# 7847   s7848  TV Show                  Red vs. Blue                   NaN
# 8182   s8183  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...

# %%
data.sort_values(by='release_year')
# Out:
#      show_id     type                         title              director  \
# 5957   s5958    Movie          To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show               Dinner for Five                   NaN
# 5956   s5957    Movie       Just Another Love Story          Ole Bornedal
# 5955   s5956    Movie                      Splatter             Joe Dante
# 7370   s7371    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 7196   s7197  TV Show                      Kikoriki                   NaN
# 7254   s7255  TV Show           La Familia P. Luche                   NaN
# 7406   s7407  TV Show                         Maron                   NaN
# 7847   s7848  TV Show                  Red vs. Blue                   NaN
# 8182   s8183  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...

# %%
data.sort_values(by='release_year',ascending=False).head(5)
# Out:
#      show_id     type                               title         director  \
# 0         s1    Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997    Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006    Movie  Keymon and Nani in Space Adventure              NaN
# 1004   s1005  TV Show                  Izzy's Koala World              NaN
# 1003   s1004  TV Show                                Zero              NaN
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 996   Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...          Japan
# 1005                                                NaN            NaN
# 1004                         Izzy Bee, Ali Bee, Tim Bee      Australia
# 1003  Giuseppe Dave Seke, Haroun Fall, Beatrice Gran...          Italy
#
#      date_added  release_year rating   duration  \
# ...

# %% [markdown]
# # HIGHEST NUMBER OF TV SHOWS COUNTRY

# %%
tv_show=data[data['type']=='TV Show']
tv_show
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
tv_show.country
# Out:
# 1                                        South Africa
# 2                                                 NaN
# 3                                                 NaN
# 4                                               India
# 5                                                 NaN
#                             ...
# 8795                                    Japan, Canada
# 8796                                           Turkey
# 8797    United States, France, South Korea, Indonesia
# 8800                                         Pakistan
# 8803                                              NaN
# Name: country, Length: 2676, dtype: object

# %%
tv_show.country.value_counts().head(1)                               ####### ans= united states
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# # FIND THE PARTICULAR TV SHOW THAT NAME IS CHOTA BHEEM

# %%
data[(data['type']=='TV Show') & (data['title']=='Chhota Bheem')]
# Out:
#    show_id     type         title director  \
# 39     s40  TV Show  Chhota Bheem      NaN
#
#                                                  cast country date_added  \
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India  16-Sep-21
#
#     release_year rating   duration listed_in  \
# 39        2021.0  TV-Y7  3 Seasons  Kids' TV
#
#                                           description     Date_N
# 39  A brave, energetic little boy with superhuman ... 2021-09-16
